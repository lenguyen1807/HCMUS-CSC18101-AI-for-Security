# %% [markdown]
# - Thành viên nhóm:
#     - 21120205 Nguyễn Tạ Bảo
#     - 21120511 Lê Nguyễn

# %%
# !pip install chainlit scikit-learn pandas joblib
# Out:
# Requirement already satisfied: chainlit in /home/nguyen/miniconda3/envs/ai4sec/lib/python3.10/site-packages (1.2.0)
# Requirement already satisfied: scikit-learn in /home/nguyen/miniconda3/envs/ai4sec/lib/python3.10/site-packages (1.5.2)
# Requirement already satisfied: pandas in /home/nguyen/miniconda3/envs/ai4sec/lib/python3.10/site-packages (2.2.3)
# Requirement already satisfied: joblib in /home/nguyen/miniconda3/envs/ai4sec/lib/python3.10/site-packages (1.4.2)
# Requirement already satisfied: aiofiles<24.0.0,>=23.1.0 in /home/nguyen/miniconda3/envs/ai4sec/lib/python3.10/site-packages (from chainlit) (23.2.1)
# Requirement already satisfied: asyncer<0.0.8,>=0.0.7 in /home/nguyen/miniconda3/envs/ai4sec/lib/python3.10/site-packages (from chainlit) (0.0.7)
# Requirement already satisfied: click<9.0.0,>=8.1.3 in /home/nguyen/miniconda3/envs/ai4sec/lib/python3.10/site-packages (from chainlit) (8.1.7)
# Requirement already satisfied: dataclasses_json<0.7.0,>=0.6.7 in /home/nguyen/miniconda3/envs/ai4sec/lib/python3.10/site-packages (from chainlit) (0.6.7)
# Requirement already satisfied: fastapi<0.113,>=0.110.1 in /home/nguyen/miniconda3/envs/ai4sec/lib/python3.10/site-packages (from chainlit) (0.112.4)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in /home/nguyen/miniconda3/envs/ai4sec/lib/python3.10/site-packages (from chainlit) (1.2.0)
# Requirement already satisfied: httpx>=0.23.0 in /home/nguyen/miniconda3/envs/ai4sec/lib/python3.10/site-packages (from chainlit) (0.27.2)
# Requirement already satisfied: lazify<0.5.0,>=0.4.0 in /home/nguyen/miniconda3/envs/ai4sec/lib/python3.10/site-packages (from chainlit) (0.4.0)
# Requirement already satisfied: literalai==0.0.607 in /home/nguyen/miniconda3/envs/ai4sec/lib/python3.10/site-packages (from chainlit) (0.0.607)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.6.0 in /home/nguyen/miniconda3/envs/ai4sec/lib/python3.10/site-packages (from chainlit) (1.6.0)
# Requirement already satisfied: numpy<2.0,>=1.26 in /home/nguyen/miniconda3/envs/ai4sec/lib/python3.10/site-packages (from chainlit) (1.26.4)
# Requirement already satisfied: packaging<24.0,>=23.1 in /home/nguyen/miniconda3/envs/ai4sec/lib/python3.10/site-packages (from chainlit) (23.2)
# Requirement already satisfied: pydantic<3,>=1 in /home/nguyen/miniconda3/envs/ai4sec/lib/python3.10/site-packages (from chainlit) (2.9.2)
# Requirement already satisfied: pyjwt<3.0.0,>=2.8.0 in /home/nguyen/miniconda3/envs/ai4sec/lib/python3.10/site-packages (from chainlit) (2.9.0)
# Requirement already satisfied: python-dotenv<2.0.0,>=1.0.0 in /home/nguyen/miniconda3/envs/ai4sec/lib/python3.10/site-packages (from chainlit) (1.0.1)
# Requirement already satisfied: python-multipart<0.0.10,>=0.0.9 in /home/nguyen/miniconda3/envs/ai4sec/lib/python3.10/site-packages (from chainlit) (0.0.9)
# Requirement already satisfied: python-socketio<6.0.0,>=5.11.0 in /home/nguyen/miniconda3/envs/ai4sec/lib/python3.10/site-packages (from chainlit) (5.11.4)
# Requirement already satisfied: starlette<0.38.0,>=0.37.2 in /home/nguyen/miniconda3/envs/ai4sec/lib/python3.10/site-packages (from chainlit) (0.37.2)
# Requirement already satisfied: syncer<3.0.0,>=2.0.3 in /home/nguyen/miniconda3/envs/ai4sec/lib/python3.10/site-packages (from chainlit) (2.0.3)
# Requirement already satisfied: tomli<3.0.0,>=2.0.1 in /home/nguyen/miniconda3/envs/ai4sec/lib/python3.10/site-packages (from chainlit) (2.0.2)
# Requirement already satisfied: uptrace<2.0.0,>=1.22.0 in /home/nguyen/miniconda3/envs/ai4sec/lib/python3.10/site-packages (from chainlit) (1.27.0)
# Requirement already satisfied: uvicorn<0.26.0,>=0.25.0 in /home/nguyen/miniconda3/envs/ai4sec/lib/python3.10/site-packages (from chainlit) (0.25.0)
# Requirement already satisfied: watchfiles<0.21.0,>=0.20.0 in /home/nguyen/miniconda3/envs/ai4sec/lib/python3.10/site-packages (from chainlit) (0.20.0)
# Requirement already satisfied: chevron>=0.14.0 in /home/nguyen/miniconda3/envs/ai4sec/lib/python3.10/site-packages (from literalai==0.0.607->chainlit) (0.14.0)
# Requirement already satisfied: scipy>=1.6.0 in /home/nguyen/miniconda3/envs/ai4sec/lib/python3.10/site-packages (from scikit-learn) (1.14.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/nguyen/miniconda3/envs/ai4sec/lib/python3.10/site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/nguyen/miniconda3/envs/ai4sec/lib/python3.10/site-packages (from pandas) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /home/nguyen/miniconda3/envs/ai4sec/lib/python3.10/site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/nguyen/miniconda3/envs/ai4sec/lib/python3.10/site-packages (from pandas) (2024.2)
# Requirement already satisfied: anyio<5.0,>=3.4.0 in /home/nguyen/miniconda3/envs/ai4sec/lib/python3.10/site-packages (from asyncer<0.0.8,>=0.0.7->chainlit) (4.6.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /home/nguyen/miniconda3/envs/ai4sec/lib/python3.10/site-packages (from dataclasses_json<0.7.0,>=0.6.7->chainlit) (3.22.0)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /home/nguyen/miniconda3/envs/ai4sec/lib/python3.10/site-packages (from dataclasses_json<0.7.0,>=0.6.7->chainlit) (0.9.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/nguyen/miniconda3/envs/ai4sec/lib/python3.10/site-packages (from fastapi<0.113,>=0.110.1->chainlit) (4.12.2)
# Requirement already satisfied: certifi in /home/nguyen/miniconda3/envs/ai4sec/lib/python3.10/site-packages (from httpx>=0.23.0->chainlit) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /home/nguyen/miniconda3/envs/ai4sec/lib/python3.10/site-packages (from httpx>=0.23.0->chainlit) (1.0.6)
# Requirement already satisfied: idna in /home/nguyen/miniconda3/envs/ai4sec/lib/python3.10/site-packages (from httpx>=0.23.0->chainlit) (3.10)
# Requirement already satisfied: sniffio in /home/nguyen/miniconda3/envs/ai4sec/lib/python3.10/site-packages (from httpx>=0.23.0->chainlit) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/nguyen/miniconda3/envs/ai4sec/lib/python3.10/site-packages (from httpcore==1.*->httpx>=0.23.0->chainlit) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/nguyen/miniconda3/envs/ai4sec/lib/python3.10/site-packages (from pydantic<3,>=1->chainlit) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /home/nguyen/miniconda3/envs/ai4sec/lib/python3.10/site-packages (from pydantic<3,>=1->chainlit) (2.23.4)
# Requirement already satisfied: six>=1.5 in /home/nguyen/miniconda3/envs/ai4sec/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: bidict>=0.21.0 in /home/nguyen/miniconda3/envs/ai4sec/lib/python3.10/site-packages (from python-socketio<6.0.0,>=5.11.0->chainlit) (0.23.1)
# Requirement already satisfied: python-engineio>=4.8.0 in /home/nguyen/miniconda3/envs/ai4sec/lib/python3.10/site-packages (from python-socketio<6.0.0,>=5.11.0->chainlit) (4.9.1)
# Requirement already satisfied: opentelemetry-api~=1.27 in /home/nguyen/miniconda3/envs/ai4sec/lib/python3.10/site-packages (from uptrace<2.0.0,>=1.22.0->chainlit) (1.27.0)
# Requirement already satisfied: opentelemetry-exporter-otlp~=1.27 in /home/nguyen/miniconda3/envs/ai4sec/lib/python3.10/site-packages (from uptrace<2.0.0,>=1.22.0->chainlit) (1.27.0)
# Requirement already satisfied: opentelemetry-instrumentation~=0.48b0 in /home/nguyen/miniconda3/envs/ai4sec/lib/python3.10/site-packages (from uptrace<2.0.0,>=1.22.0->chainlit) (0.48b0)
# Requirement already satisfied: opentelemetry-sdk~=1.27 in /home/nguyen/miniconda3/envs/ai4sec/lib/python3.10/site-packages (from uptrace<2.0.0,>=1.22.0->chainlit) (1.27.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/nguyen/miniconda3/envs/ai4sec/lib/python3.10/site-packages (from anyio<5.0,>=3.4.0->asyncer<0.0.8,>=0.0.7->chainlit) (1.2.2)
# Requirement already satisfied: deprecated>=1.2.6 in /home/nguyen/miniconda3/envs/ai4sec/lib/python3.10/site-packages (from opentelemetry-api~=1.27->uptrace<2.0.0,>=1.22.0->chainlit) (1.2.14)
# Requirement already satisfied: importlib-metadata<=8.4.0,>=6.0 in /home/nguyen/miniconda3/envs/ai4sec/lib/python3.10/site-packages (from opentelemetry-api~=1.27->uptrace<2.0.0,>=1.22.0->chainlit) (8.4.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc==1.27.0 in /home/nguyen/miniconda3/envs/ai4sec/lib/python3.10/site-packages (from opentelemetry-exporter-otlp~=1.27->uptrace<2.0.0,>=1.22.0->chainlit) (1.27.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http==1.27.0 in /home/nguyen/miniconda3/envs/ai4sec/lib/python3.10/site-packages (from opentelemetry-exporter-otlp~=1.27->uptrace<2.0.0,>=1.22.0->chainlit) (1.27.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /home/nguyen/miniconda3/envs/ai4sec/lib/python3.10/site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.27.0->opentelemetry-exporter-otlp~=1.27->uptrace<2.0.0,>=1.22.0->chainlit) (1.65.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.0.0 in /home/nguyen/miniconda3/envs/ai4sec/lib/python3.10/site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.27.0->opentelemetry-exporter-otlp~=1.27->uptrace<2.0.0,>=1.22.0->chainlit) (1.66.2)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.27.0 in /home/nguyen/miniconda3/envs/ai4sec/lib/python3.10/site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.27.0->opentelemetry-exporter-otlp~=1.27->uptrace<2.0.0,>=1.22.0->chainlit) (1.27.0)
# Requirement already satisfied: opentelemetry-proto==1.27.0 in /home/nguyen/miniconda3/envs/ai4sec/lib/python3.10/site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.27.0->opentelemetry-exporter-otlp~=1.27->uptrace<2.0.0,>=1.22.0->chainlit) (1.27.0)
# Requirement already satisfied: requests~=2.7 in /home/nguyen/miniconda3/envs/ai4sec/lib/python3.10/site-packages (from opentelemetry-exporter-otlp-proto-http==1.27.0->opentelemetry-exporter-otlp~=1.27->uptrace<2.0.0,>=1.22.0->chainlit) (2.32.3)
# Requirement already satisfied: protobuf<5.0,>=3.19 in /home/nguyen/miniconda3/envs/ai4sec/lib/python3.10/site-packages (from opentelemetry-proto==1.27.0->opentelemetry-exporter-otlp-proto-grpc==1.27.0->opentelemetry-exporter-otlp~=1.27->uptrace<2.0.0,>=1.22.0->chainlit) (4.25.5)
# Requirement already satisfied: setuptools>=16.0 in /home/nguyen/miniconda3/envs/ai4sec/lib/python3.10/site-packages (from opentelemetry-instrumentation~=0.48b0->uptrace<2.0.0,>=1.22.0->chainlit) (75.1.0)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in /home/nguyen/miniconda3/envs/ai4sec/lib/python3.10/site-packages (from opentelemetry-instrumentation~=0.48b0->uptrace<2.0.0,>=1.22.0->chainlit) (1.16.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.48b0 in /home/nguyen/miniconda3/envs/ai4sec/lib/python3.10/site-packages (from opentelemetry-sdk~=1.27->uptrace<2.0.0,>=1.22.0->chainlit) (0.48b0)
# Requirement already satisfied: simple-websocket>=0.10.0 in /home/nguyen/miniconda3/envs/ai4sec/lib/python3.10/site-packages (from python-engineio>=4.8.0->python-socketio<6.0.0,>=5.11.0->chainlit) (1.1.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /home/nguyen/miniconda3/envs/ai4sec/lib/python3.10/site-packages (from typing-inspect<1,>=0.4.0->dataclasses_json<0.7.0,>=0.6.7->chainlit) (1.0.0)
# Requirement already satisfied: zipp>=0.5 in /home/nguyen/miniconda3/envs/ai4sec/lib/python3.10/site-packages (from importlib-metadata<=8.4.0,>=6.0->opentelemetry-api~=1.27->uptrace<2.0.0,>=1.22.0->chainlit) (3.20.2)
# Requirement already satisfied: wsproto in /home/nguyen/miniconda3/envs/ai4sec/lib/python3.10/site-packages (from simple-websocket>=0.10.0->python-engineio>=4.8.0->python-socketio<6.0.0,>=5.11.0->chainlit) (1.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/nguyen/miniconda3/envs/ai4sec/lib/python3.10/site-packages (from requests~=2.7->opentelemetry-exporter-otlp-proto-http==1.27.0->opentelemetry-exporter-otlp~=1.27->uptrace<2.0.0,>=1.22.0->chainlit) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/nguyen/miniconda3/envs/ai4sec/lib/python3.10/site-packages (from requests~=2.7->opentelemetry-exporter-otlp-proto-http==1.27.0->opentelemetry-exporter-otlp~=1.27->uptrace<2.0.0,>=1.22.0->chainlit) (2.2.3)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
import chainlit as cl
from io import StringIO
import threading
import joblib

# %% [markdown]
# # 1 - Đọc dữ liệu

# %%
train_data = pd.read_csv ('./train.csv')
test_data = pd.read_csv ('./val.csv')

# %% [markdown]
# ## 1.3 -  5 dòng đầu tiên của dữ liệu train và test

# %%
train_data.head(5)
# Out:
#    Unnamed: 0  Message ID                       Subject  \
# 0           0           0  christmas tree farm pictures
# 1           1           1      vastar resources , inc .
# 2           2           2  calpine daily gas nomination
# 3           3           3                    re : issue
# 4           5           5      mcmullen gas for 11 / 99
#
#                                              Message Spam/Ham     split
# 0                                                NaN      ham  0.038415
# 1  gary , production from the high island larger ...      ham  0.696509
# 2             - calpine daily gas nomination 1 . doc      ham  0.587792
# 3  fyi - see note below - already done .\nstella\...      ham -0.055438
# 4  jackie ,\nsince the inlet to 3 river plant is ...      ham -0.419658

# %%
test_data.head(5)
# Out:
#    Unnamed: 0  Message ID                                      Subject  \
# 0          23          23                                miscellaneous
# 1          24          24  re : purge of old contract _ event _ status
# 2          32          32                         valero 8018 and 1394
# 3          37          37               01 / 00 natural gas nomination
# 4          43          43                        re : misc . questions
#
#                                              Message Spam/Ham     split
# 0  - - - - - - - - - - - - - - - - - - - - - - fo...      ham -0.351998
# 1  fyi - what do you all think ?\n- - - - - - - -...      ham  0.257704
# 2  it is my understanding the outages valero incu...      ham  0.091200
# 3  enron methanol company nominates the following...      ham -1.745133
# 4  - - - - - - - - - - - - - - - - - - - - - - fo...      ham -1.911987

# %% [markdown]
# # 2 - Tiền xử lý dữ liệu

# %%
# Thay thế các giá trị NaN trong cột Subject bằng chuỗi rỗng
train_data['Subject'] = train_data['Subject'].fillna ('')
test_data['Subject'] = test_data['Subject'].fillna ('')

train_data['Message'] = train_data['Message'].fillna ('')
test_data['Message'] = test_data['Message'].fillna ('')

# %%
# Gộp cột Subject và Message lại thành một cột duy nhất là Text 
train_data['Text'] = train_data['Subject'] + ' ' + train_data['Message']
test_data['Text'] = test_data['Subject'] + ' ' + test_data['Message']

# %%
# Chia ra tập huấn luyện và tập kiểm thử 
X_train = train_data['Text']
Y_train = train_data['Spam/Ham']

X_test = test_data['Text']
Y_test = test_data['Spam/Ham']

# %% [markdown]
# # 3 - Xây dựng mô hình

# %%
# Trích xuất đặc trưng bằng TF-IDF
tfidf = TfidfVectorizer(max_features=5000) # giới hạn số lượng từ vựng tối đa là 5000
X_train_tfidf = tfidf.fit_transform(X_train)
X_test_tfidf = tfidf.transform(X_test)

# %%
# Huấn luyện mô hình Naive Bayes
model = MultinomialNB()
model.fit(X_train_tfidf, Y_train)
# Out:
# MultinomialNB()

# %%
# Save the model and vectorizer
joblib.dump(model, 'spam_classifier_model.pkl')
joblib.dump(tfidf, 'tfidf_vectorizer.pkl')
# Out:
# ['tfidf_vectorizer.pkl']

# %%
# Dự đoán nhãn của tập kiểm thử
Y_pred = model.predict(X_test_tfidf)

# %%
# Đánh giá mô hình bằng các độ đo Accuracy, Precision, Recall, F1
accuracy = accuracy_score(Y_test, Y_pred)
precision = precision_score(Y_test, Y_pred , pos_label='spam')
recall = recall_score(Y_test, Y_pred, pos_label='spam')
f1 = f1_score(Y_test, Y_pred , pos_label='spam')

print(f"Accuracy: {accuracy}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1 Score: {f1}")
# Out:
# Accuracy: 0.9818417639429312
# Precision: 0.9753943217665615
# Recall: 0.9891234804862444
# F1 Score: 0.9822109275730623

# %% [markdown]
# # 4 - Thử nghiệm thực tế

# %%
def preprocess_text(text, vectorizer):
    # Giả sử sử dụng cùng vectorizer (TF-IDF)
    return vectorizer.transform([text])

def predict_email(model, vectorizer):
    subject = input("Nhập tiêu đề email: ")
    message = input("Nhập nội dung email: ")

    # Ghép subject và message
    email_text = subject + " " + message
    
    print(f"Subject: {subject}\nMessage: {message}")

    # Tiền xử lý giống như đã làm với tập dữ liệu ban đầu
    email_vectorized = preprocess_text(email_text, vectorizer)

    # Dự đoán
    prediction = model.predict(email_vectorized)

    # Trả về kết quả
    print("Dự đoán: ", "Spam" if prediction[0] == 'spam' else "Ham")

# Ví dụ sử dụng:
predict_email(model, tfidf)  # model là mô hình đã huấn luyện, tfidf là vectorizer
# Out:
# Subject: Hello who are you
# Message: I'm spam email
# Dự đoán:  Spam

# %%
def evaluate_on_csv(model, vectorizer, file_path):
    # Đọc file CSV
    data = pd.read_csv(file_path)
    # Thay thế NaN bằng chuỗi rỗng
    data['Subject'] = data['Subject'].fillna('')
    data['Message'] = data['Message'].fillna('')
    
    # Kết hợp 'subject' và 'message' thành một chuỗi
    data['Text'] = data['Subject'] + " " + data['Message']

    # Tiền xử lý dữ liệu
    X = vectorizer.transform(data['Text'])  # Tiền xử lý giống với quá trình huấn luyện
    y_true = data['Spam/Ham']  # Nhãn thực tế (spam hoặc ham)

    # Dự đoán
    y_pred = model.predict(X)

    # Đánh giá kết quả
    accuracy = accuracy_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred, pos_label='spam')
    recall = recall_score(y_true, y_pred, pos_label='spam')
    f1 = f1_score(y_true, y_pred, pos_label='spam')

    print(f"Accuracy: {accuracy}")
    print(f"Precision: {precision}")
    print(f"Recall: {recall}")
    print(f"F1 Score: {f1}")

# Ví dụ sử dụng:
evaluate_on_csv(model, tfidf, "val.csv")  # model là mô hình đã huấn luyện, tfidf là vectorizer
# Out:
# Accuracy: 0.9818417639429312
# Precision: 0.9753943217665615
# Recall: 0.9891234804862444
# F1 Score: 0.9822109275730623
