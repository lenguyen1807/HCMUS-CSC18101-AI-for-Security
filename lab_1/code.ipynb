# %% [markdown]
# - Thành viên nhóm
#     - 21120205 - Nguyễn Tạ Bảo
#     - 21120511 - Lê Nguyễn

# %%
# !pip install chainlit
# Out:
# Collecting chainlit
#   Downloading chainlit-1.2.0-py3-none-any.whl.metadata (6.2 kB)
# Collecting aiofiles<24.0.0,>=23.1.0 (from chainlit)
#   Downloading aiofiles-23.2.1-py3-none-any.whl.metadata (9.7 kB)
# Collecting asyncer<0.0.8,>=0.0.7 (from chainlit)
#   Downloading asyncer-0.0.7-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: click<9.0.0,>=8.1.3 in c:\users\bafo\.conda\envs\default_env\lib\site-packages (from chainlit) (8.1.7)
# Collecting dataclasses_json<0.7.0,>=0.6.7 (from chainlit)
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting fastapi<0.113,>=0.110.1 (from chainlit)
#   Downloading fastapi-0.112.4-py3-none-any.whl.metadata (27 kB)
# Collecting filetype<2.0.0,>=1.2.0 (from chainlit)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting httpx>=0.23.0 (from chainlit)
#   Using cached httpx-0.27.2-py3-none-any.whl.metadata (7.1 kB)
# Collecting lazify<0.5.0,>=0.4.0 (from chainlit)
#   Downloading Lazify-0.4.0-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting literalai==0.0.607 (from chainlit)
#   Downloading literalai-0.0.607.tar.gz (49 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.6.0 in c:\users\bafo\.conda\envs\default_env\lib\site-packages (from chainlit) (1.6.0)
# Collecting numpy<2.0,>=1.26 (from chainlit)
#   Downloading numpy-1.26.4-cp310-cp310-win_amd64.whl.metadata (61 kB)
# Collecting packaging<24.0,>=23.1 (from chainlit)
#   Using cached packaging-23.2-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: pydantic<3,>=1 in c:\users\bafo\.conda\envs\default_env\lib\site-packages (from chainlit) (2.9.1)
# Collecting pyjwt<3.0.0,>=2.8.0 (from chainlit)
#   Using cached PyJWT-2.9.0-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: python-dotenv<2.0.0,>=1.0.0 in c:\users\bafo\.conda\envs\default_env\lib\site-packages (from chainlit) (1.0.1)
# Requirement already satisfied: python-multipart<0.0.10,>=0.0.9 in c:\users\bafo\.conda\envs\default_env\lib\site-packages (from chainlit) (0.0.9)
# Collecting python-socketio<6.0.0,>=5.11.0 (from chainlit)
#   Downloading python_socketio-5.11.4-py3-none-any.whl.metadata (3.2 kB)
# Collecting starlette<0.38.0,>=0.37.2 (from chainlit)
#   Using cached starlette-0.37.2-py3-none-any.whl.metadata (5.9 kB)
# Collecting syncer<3.0.0,>=2.0.3 (from chainlit)
#   Downloading syncer-2.0.3.tar.gz (11 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting tomli<3.0.0,>=2.0.1 (from chainlit)
#   Downloading tomli-2.0.2-py3-none-any.whl.metadata (10.0 kB)
# Collecting uptrace<2.0.0,>=1.22.0 (from chainlit)
#   Downloading uptrace-1.27.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting uvicorn<0.26.0,>=0.25.0 (from chainlit)
#   Downloading uvicorn-0.25.0-py3-none-any.whl.metadata (6.4 kB)
# Collecting watchfiles<0.21.0,>=0.20.0 (from chainlit)
#   Downloading watchfiles-0.20.0-cp37-abi3-win_amd64.whl.metadata (5.0 kB)
# Collecting chevron>=0.14.0 (from literalai==0.0.607->chainlit)
#   Downloading chevron-0.14.0-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: anyio<5.0,>=3.4.0 in c:\users\bafo\.conda\envs\default_env\lib\site-packages (from asyncer<0.0.8,>=0.0.7->chainlit) (4.4.0)
# Requirement already satisfied: colorama in c:\users\bafo\.conda\envs\default_env\lib\site-packages (from click<9.0.0,>=8.1.3->chainlit) (0.4.6)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\bafo\.conda\envs\default_env\lib\site-packages (from dataclasses_json<0.7.0,>=0.6.7->chainlit) (3.22.0)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses_json<0.7.0,>=0.6.7->chainlit)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\bafo\.conda\envs\default_env\lib\site-packages (from fastapi<0.113,>=0.110.1->chainlit) (4.12.2)
# Requirement already satisfied: certifi in c:\users\bafo\.conda\envs\default_env\lib\site-packages (from httpx>=0.23.0->chainlit) (2024.8.30)
# Collecting httpcore==1.* (from httpx>=0.23.0->chainlit)
#   Downloading httpcore-1.0.6-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: idna in c:\users\bafo\.conda\envs\default_env\lib\site-packages (from httpx>=0.23.0->chainlit) (2.10)
# Requirement already satisfied: sniffio in c:\users\bafo\.conda\envs\default_env\lib\site-packages (from httpx>=0.23.0->chainlit) (1.3.1)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx>=0.23.0->chainlit)
#   Using cached h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\bafo\.conda\envs\default_env\lib\site-packages (from pydantic<3,>=1->chainlit) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.3 in c:\users\bafo\.conda\envs\default_env\lib\site-packages (from pydantic<3,>=1->chainlit) (2.23.3)
# Collecting bidict>=0.21.0 (from python-socketio<6.0.0,>=5.11.0->chainlit)
#   Downloading bidict-0.23.1-py3-none-any.whl.metadata (8.7 kB)
# Collecting python-engineio>=4.8.0 (from python-socketio<6.0.0,>=5.11.0->chainlit)
#   Downloading python_engineio-4.9.1-py3-none-any.whl.metadata (2.2 kB)
# Collecting opentelemetry-api~=1.27 (from uptrace<2.0.0,>=1.22.0->chainlit)
#   Downloading opentelemetry_api-1.27.0-py3-none-any.whl.metadata (1.4 kB)
# Collecting opentelemetry-exporter-otlp~=1.27 (from uptrace<2.0.0,>=1.22.0->chainlit)
#   Downloading opentelemetry_exporter_otlp-1.27.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-instrumentation~=0.48b0 (from uptrace<2.0.0,>=1.22.0->chainlit)
#   Downloading opentelemetry_instrumentation-0.48b0-py3-none-any.whl.metadata (6.1 kB)
# Collecting opentelemetry-sdk~=1.27 (from uptrace<2.0.0,>=1.22.0->chainlit)
#   Downloading opentelemetry_sdk-1.27.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\bafo\.conda\envs\default_env\lib\site-packages (from anyio<5.0,>=3.4.0->asyncer<0.0.8,>=0.0.7->chainlit) (1.2.2)
# Collecting deprecated>=1.2.6 (from opentelemetry-api~=1.27->uptrace<2.0.0,>=1.22.0->chainlit)
#   Using cached Deprecated-1.2.14-py2.py3-none-any.whl.metadata (5.4 kB)
# Collecting importlib-metadata<=8.4.0,>=6.0 (from opentelemetry-api~=1.27->uptrace<2.0.0,>=1.22.0->chainlit)
#   Downloading importlib_metadata-8.4.0-py3-none-any.whl.metadata (4.7 kB)
# Collecting opentelemetry-exporter-otlp-proto-grpc==1.27.0 (from opentelemetry-exporter-otlp~=1.27->uptrace<2.0.0,>=1.22.0->chainlit)
#   Downloading opentelemetry_exporter_otlp_proto_grpc-1.27.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-exporter-otlp-proto-http==1.27.0 (from opentelemetry-exporter-otlp~=1.27->uptrace<2.0.0,>=1.22.0->chainlit)
#   Downloading opentelemetry_exporter_otlp_proto_http-1.27.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting googleapis-common-protos~=1.52 (from opentelemetry-exporter-otlp-proto-grpc==1.27.0->opentelemetry-exporter-otlp~=1.27->uptrace<2.0.0,>=1.22.0->chainlit)
#   Downloading googleapis_common_protos-1.65.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: grpcio<2.0.0,>=1.0.0 in c:\users\bafo\.conda\envs\default_env\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.27.0->opentelemetry-exporter-otlp~=1.27->uptrace<2.0.0,>=1.22.0->chainlit) (1.66.1)
# Collecting opentelemetry-exporter-otlp-proto-common==1.27.0 (from opentelemetry-exporter-otlp-proto-grpc==1.27.0->opentelemetry-exporter-otlp~=1.27->uptrace<2.0.0,>=1.22.0->chainlit)
#   Downloading opentelemetry_exporter_otlp_proto_common-1.27.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting opentelemetry-proto==1.27.0 (from opentelemetry-exporter-otlp-proto-grpc==1.27.0->opentelemetry-exporter-otlp~=1.27->uptrace<2.0.0,>=1.22.0->chainlit)
#   Downloading opentelemetry_proto-1.27.0-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: requests~=2.7 in c:\users\bafo\.conda\envs\default_env\lib\site-packages (from opentelemetry-exporter-otlp-proto-http==1.27.0->opentelemetry-exporter-otlp~=1.27->uptrace<2.0.0,>=1.22.0->chainlit) (2.32.3)
# Collecting protobuf<5.0,>=3.19 (from opentelemetry-proto==1.27.0->opentelemetry-exporter-otlp-proto-grpc==1.27.0->opentelemetry-exporter-otlp~=1.27->uptrace<2.0.0,>=1.22.0->chainlit)
#   Downloading protobuf-4.25.5-cp310-abi3-win_amd64.whl.metadata (541 bytes)
# Requirement already satisfied: setuptools>=16.0 in c:\users\bafo\.conda\envs\default_env\lib\site-packages (from opentelemetry-instrumentation~=0.48b0->uptrace<2.0.0,>=1.22.0->chainlit) (72.1.0)
# Collecting wrapt<2.0.0,>=1.0.0 (from opentelemetry-instrumentation~=0.48b0->uptrace<2.0.0,>=1.22.0->chainlit)
#   Using cached wrapt-1.16.0-cp310-cp310-win_amd64.whl.metadata (6.8 kB)
# Collecting opentelemetry-semantic-conventions==0.48b0 (from opentelemetry-sdk~=1.27->uptrace<2.0.0,>=1.22.0->chainlit)
#   Downloading opentelemetry_semantic_conventions-0.48b0-py3-none-any.whl.metadata (2.4 kB)
# Collecting simple-websocket>=0.10.0 (from python-engineio>=4.8.0->python-socketio<6.0.0,>=5.11.0->chainlit)
#   Downloading simple_websocket-1.0.0-py3-none-any.whl.metadata (1.3 kB)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses_json<0.7.0,>=0.6.7->chainlit)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: zipp>=0.5 in c:\users\bafo\.conda\envs\default_env\lib\site-packages (from importlib-metadata<=8.4.0,>=6.0->opentelemetry-api~=1.27->uptrace<2.0.0,>=1.22.0->chainlit) (3.20.2)
# Collecting wsproto (from simple-websocket>=0.10.0->python-engineio>=4.8.0->python-socketio<6.0.0,>=5.11.0->chainlit)
#   Downloading wsproto-1.2.0-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\bafo\.conda\envs\default_env\lib\site-packages (from requests~=2.7->opentelemetry-exporter-otlp-proto-http==1.27.0->opentelemetry-exporter-otlp~=1.27->uptrace<2.0.0,>=1.22.0->chainlit) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\bafo\.conda\envs\default_env\lib\site-packages (from requests~=2.7->opentelemetry-exporter-otlp-proto-http==1.27.0->opentelemetry-exporter-otlp~=1.27->uptrace<2.0.0,>=1.22.0->chainlit) (2.2.3)
# Downloading chainlit-1.2.0-py3-none-any.whl (4.3 MB)
#    ---------------------------------------- 0.0/4.3 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/4.3 MB ? eta -:--:--
#    ------- -------------------------------- 0.8/4.3 MB 1.9 MB/s eta 0:00:02
#    ------------ --------------------------- 1.3/4.3 MB 2.3 MB/s eta 0:00:02
#    ---------------- ----------------------- 1.8/4.3 MB 2.3 MB/s eta 0:00:02
#    --------------------- ------------------ 2.4/4.3 MB 2.5 MB/s eta 0:00:01
#    ------------------------ --------------- 2.6/4.3 MB 2.4 MB/s eta 0:00:01
#    ------------------------------- -------- 3.4/4.3 MB 2.4 MB/s eta 0:00:01
#    -------------------------------------- - 4.2/4.3 MB 2.6 MB/s eta 0:00:01
#    ---------------------------------------- 4.3/4.3 MB 2.5 MB/s eta 0:00:00
# Downloading aiofiles-23.2.1-py3-none-any.whl (15 kB)
# Downloading asyncer-0.0.7-py3-none-any.whl (8.5 kB)
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading fastapi-0.112.4-py3-none-any.whl (93 kB)
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Using cached httpx-0.27.2-py3-none-any.whl (76 kB)
# Downloading httpcore-1.0.6-py3-none-any.whl (78 kB)
# Downloading Lazify-0.4.0-py2.py3-none-any.whl (3.1 kB)
# Downloading numpy-1.26.4-cp310-cp310-win_amd64.whl (15.8 MB)
#    ---------------------------------------- 0.0/15.8 MB ? eta -:--:--
#     --------------------------------------- 0.3/15.8 MB ? eta -:--:--
#    - -------------------------------------- 0.5/15.8 MB 1.7 MB/s eta 0:00:10
#    -- ------------------------------------- 1.0/15.8 MB 1.7 MB/s eta 0:00:09
#    --- ------------------------------------ 1.3/15.8 MB 1.6 MB/s eta 0:00:10
#    --- ------------------------------------ 1.3/15.8 MB 1.6 MB/s eta 0:00:10
#    --- ------------------------------------ 1.6/15.8 MB 1.2 MB/s eta 0:00:12
#    ----- ---------------------------------- 2.1/15.8 MB 1.4 MB/s eta 0:00:10
#    ------ --------------------------------- 2.6/15.8 MB 1.6 MB/s eta 0:00:09
#    ------- -------------------------------- 3.1/15.8 MB 1.7 MB/s eta 0:00:08
#    --------- ------------------------------ 3.7/15.8 MB 1.8 MB/s eta 0:00:07
#    ---------- ----------------------------- 4.2/15.8 MB 1.9 MB/s eta 0:00:07
#    ----------- ---------------------------- 4.5/15.8 MB 1.9 MB/s eta 0:00:06
#    ------------- -------------------------- 5.2/15.8 MB 2.0 MB/s eta 0:00:06
#    -------------- ------------------------- 5.8/15.8 MB 2.1 MB/s eta 0:00:05
#    ----------------- ---------------------- 6.8/15.8 MB 2.2 MB/s eta 0:00:05
#    ----------------- ---------------------- 7.1/15.8 MB 2.2 MB/s eta 0:00:04
#    ------------------ --------------------- 7.3/15.8 MB 2.2 MB/s eta 0:00:04
#    ------------------- -------------------- 7.9/15.8 MB 2.1 MB/s eta 0:00:04
#    --------------------- ------------------ 8.4/15.8 MB 2.2 MB/s eta 0:00:04
#    ---------------------- ----------------- 8.9/15.8 MB 2.2 MB/s eta 0:00:04
#    ----------------------- ---------------- 9.4/15.8 MB 2.2 MB/s eta 0:00:03
#    ------------------------- -------------- 10.0/15.8 MB 2.2 MB/s eta 0:00:03
#    -------------------------- ------------- 10.5/15.8 MB 2.2 MB/s eta 0:00:03
#    ---------------------------- ----------- 11.3/15.8 MB 2.3 MB/s eta 0:00:02
#    ------------------------------ --------- 12.1/15.8 MB 2.3 MB/s eta 0:00:02
#    ------------------------------ --------- 12.1/15.8 MB 2.3 MB/s eta 0:00:02
#    ------------------------------- -------- 12.6/15.8 MB 2.3 MB/s eta 0:00:02
#    -------------------------------- ------- 12.8/15.8 MB 2.2 MB/s eta 0:00:02
#    --------------------------------- ------ 13.4/15.8 MB 2.3 MB/s eta 0:00:02
#    ------------------------------------ --- 14.4/15.8 MB 2.3 MB/s eta 0:00:01
#    ------------------------------------- -- 14.7/15.8 MB 2.3 MB/s eta 0:00:01
#    ------------------------------------- -- 14.9/15.8 MB 2.3 MB/s eta 0:00:01
#    ---------------------------------------  15.5/15.8 MB 2.3 MB/s eta 0:00:01
#    ---------------------------------------- 15.8/15.8 MB 2.3 MB/s eta 0:00:00
# Using cached packaging-23.2-py3-none-any.whl (53 kB)
# Using cached PyJWT-2.9.0-py3-none-any.whl (22 kB)
# Downloading python_socketio-5.11.4-py3-none-any.whl (76 kB)
# Using cached starlette-0.37.2-py3-none-any.whl (71 kB)
# Downloading tomli-2.0.2-py3-none-any.whl (13 kB)
# Downloading uptrace-1.27.0-py3-none-any.whl (8.6 kB)
# Downloading uvicorn-0.25.0-py3-none-any.whl (60 kB)
# Downloading watchfiles-0.20.0-cp37-abi3-win_amd64.whl (276 kB)
# Downloading bidict-0.23.1-py3-none-any.whl (32 kB)
# Downloading chevron-0.14.0-py3-none-any.whl (11 kB)
# Using cached h11-0.14.0-py3-none-any.whl (58 kB)
# Downloading opentelemetry_api-1.27.0-py3-none-any.whl (63 kB)
# Downloading opentelemetry_exporter_otlp-1.27.0-py3-none-any.whl (7.0 kB)
# Downloading opentelemetry_exporter_otlp_proto_grpc-1.27.0-py3-none-any.whl (18 kB)
# Downloading opentelemetry_exporter_otlp_proto_http-1.27.0-py3-none-any.whl (17 kB)
# Downloading opentelemetry_exporter_otlp_proto_common-1.27.0-py3-none-any.whl (17 kB)
# Downloading opentelemetry_proto-1.27.0-py3-none-any.whl (52 kB)
# Downloading opentelemetry_instrumentation-0.48b0-py3-none-any.whl (29 kB)
# Downloading opentelemetry_sdk-1.27.0-py3-none-any.whl (110 kB)
# Downloading opentelemetry_semantic_conventions-0.48b0-py3-none-any.whl (149 kB)
# Downloading python_engineio-4.9.1-py3-none-any.whl (57 kB)
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Using cached Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Downloading importlib_metadata-8.4.0-py3-none-any.whl (26 kB)
# Using cached mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Downloading simple_websocket-1.0.0-py3-none-any.whl (13 kB)
# Using cached wrapt-1.16.0-cp310-cp310-win_amd64.whl (37 kB)
# Downloading googleapis_common_protos-1.65.0-py2.py3-none-any.whl (220 kB)
# Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Downloading protobuf-4.25.5-cp310-abi3-win_amd64.whl (413 kB)
# Building wheels for collected packages: literalai, syncer
#   Building wheel for literalai (setup.py): started
#   Building wheel for literalai (setup.py): finished with status 'done'
#   Created wheel for literalai: filename=literalai-0.0.607-py3-none-any.whl size=64149 sha256=e4b28168b8594850d3819c8544d7d9debc51f3832a613cde6007f89f8a3c7f71
#   Stored in directory: c:\users\bafo\appdata\local\pip\cache\wheels\29\e9\96\826c366cb47a2d2b23265f59beb18f9d5635ab75185cff7a9e
#   Building wheel for syncer (setup.py): started
#   Building wheel for syncer (setup.py): finished with status 'done'
#   Created wheel for syncer: filename=syncer-2.0.3-py2.py3-none-any.whl size=3453 sha256=f246b0c7a4fdfe31f17acfbbfd803eaaca1a92addce6fe1ba2fb6c9c1295b91e
#   Stored in directory: c:\users\bafo\appdata\local\pip\cache\wheels\09\e4\36\bcaad665bcc2b672888ff2df1a5a1dc638378d8765055313cd
# Successfully built literalai syncer
# Installing collected packages: syncer, lazify, filetype, chevron, wrapt, tomli, pyjwt, protobuf, packaging, numpy, mypy-extensions, importlib-metadata, h11, bidict, aiofiles, wsproto, watchfiles, uvicorn, typing-inspect, starlette, opentelemetry-proto, httpcore, googleapis-common-protos, deprecated, asyncer, simple-websocket, opentelemetry-exporter-otlp-proto-common, opentelemetry-api, httpx, fastapi, dataclasses_json, python-engineio, opentelemetry-semantic-conventions, opentelemetry-instrumentation, literalai, python-socketio, opentelemetry-sdk, opentelemetry-exporter-otlp-proto-http, opentelemetry-exporter-otlp-proto-grpc, opentelemetry-exporter-otlp, uptrace, chainlit
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 5.28.1
#     Uninstalling protobuf-5.28.1:
#       Successfully uninstalled protobuf-5.28.1
#   Attempting uninstall: packaging
#     Found existing installation: packaging 24.1
#     Uninstalling packaging-24.1:
#       Successfully uninstalled packaging-24.1
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.1.1
#     Uninstalling numpy-2.1.1:
#       Successfully uninstalled numpy-2.1.1
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib_metadata 8.5.0
#     Uninstalling importlib_metadata-8.5.0:
#       Successfully uninstalled importlib_metadata-8.5.0
#   Attempting uninstall: h11
#     Found existing installation: h11 0.9.0
#     Uninstalling h11-0.9.0:
#       Successfully uninstalled h11-0.9.0
#   Attempting uninstall: watchfiles
#     Found existing installation: watchfiles 0.24.0
#     Uninstalling watchfiles-0.24.0:
#       Successfully uninstalled watchfiles-0.24.0
#   Attempting uninstall: uvicorn
#     Found existing installation: uvicorn 0.30.6
#     Uninstalling uvicorn-0.30.6:
#       Successfully uninstalled uvicorn-0.30.6
#   Attempting uninstall: starlette
#     Found existing installation: starlette 0.38.5
#     Uninstalling starlette-0.38.5:
#       Successfully uninstalled starlette-0.38.5
#   Attempting uninstall: httpcore
#     Found existing installation: httpcore 0.9.1
#     Uninstalling httpcore-0.9.1:
#       Successfully uninstalled httpcore-0.9.1
#   Attempting uninstall: httpx
#     Found existing installation: httpx 0.13.3
#     Uninstalling httpx-0.13.3:
#       Successfully uninstalled httpx-0.13.3
#   Attempting uninstall: fastapi
#     Found existing installation: fastapi 0.114.2
#     Uninstalling fastapi-0.114.2:
#       Successfully uninstalled fastapi-0.114.2
# Successfully installed aiofiles-23.2.1 asyncer-0.0.7 bidict-0.23.1 chainlit-1.2.0 chevron-0.14.0 dataclasses_json-0.6.7 deprecated-1.2.14 fastapi-0.112.4 filetype-1.2.0 googleapis-common-protos-1.65.0 h11-0.14.0 httpcore-1.0.6 httpx-0.27.2 importlib-metadata-8.4.0 lazify-0.4.0 literalai-0.0.607 mypy-extensions-1.0.0 numpy-1.26.4 opentelemetry-api-1.27.0 opentelemetry-exporter-otlp-1.27.0 opentelemetry-exporter-otlp-proto-common-1.27.0 opentelemetry-exporter-otlp-proto-grpc-1.27.0 opentelemetry-exporter-otlp-proto-http-1.27.0 opentelemetry-instrumentation-0.48b0 opentelemetry-proto-1.27.0 opentelemetry-sdk-1.27.0 opentelemetry-semantic-conventions-0.48b0 packaging-23.2 protobuf-4.25.5 pyjwt-2.9.0 python-engineio-4.9.1 python-socketio-5.11.4 simple-websocket-1.0.0 starlette-0.37.2 syncer-2.0.3 tomli-2.0.2 typing-inspect-0.9.0 uptrace-1.27.0 uvicorn-0.25.0 watchfiles-0.20.0 wrapt-1.16.0 wsproto-1.2.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# googletrans 4.0.0rc1 requires httpx==0.13.3, but you have httpx 0.27.2 which is incompatible.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
import chainlit as cl
from io import StringIO
import threading
import joblib

# %% [markdown]
# # 1 - Đọc dữ liệu

# %%
train_data = pd.read_csv ('./train.csv')
test_data = pd.read_csv ('./val.csv')

# %% [markdown]
# ## 1.3 -  5 dòng đầu tiên của dữ liệu train và test

# %%
train_data.head (5)
# Out:
#    Unnamed: 0  Message ID                       Subject  \
# 0           0           0  christmas tree farm pictures
# 1           1           1      vastar resources , inc .
# 2           2           2  calpine daily gas nomination
# 3           3           3                    re : issue
# 4           5           5      mcmullen gas for 11 / 99
#
#                                              Message Spam/Ham     split
# 0                                                NaN      ham  0.038415
# 1  gary , production from the high island larger ...      ham  0.696509
# 2             - calpine daily gas nomination 1 . doc      ham  0.587792
# 3  fyi - see note below - already done .\nstella\...      ham -0.055438
# 4  jackie ,\nsince the inlet to 3 river plant is ...      ham -0.419658

# %%
test_data.head (5)
# Out:
#    Unnamed: 0  Message ID                                      Subject  \
# 0          23          23                                miscellaneous
# 1          24          24  re : purge of old contract _ event _ status
# 2          32          32                         valero 8018 and 1394
# 3          37          37               01 / 00 natural gas nomination
# 4          43          43                        re : misc . questions
#
#                                              Message Spam/Ham     split
# 0  - - - - - - - - - - - - - - - - - - - - - - fo...      ham -0.351998
# 1  fyi - what do you all think ?\n- - - - - - - -...      ham  0.257704
# 2  it is my understanding the outages valero incu...      ham  0.091200
# 3  enron methanol company nominates the following...      ham -1.745133
# 4  - - - - - - - - - - - - - - - - - - - - - - fo...      ham -1.911987

# %% [markdown]
# # 2 - Tiền xử lý dữ liệu

# %%
# Thay thế các giá trị NaN trong cột Subject bằng chuỗi rỗng
train_data['Subject'] = train_data['Subject'].fillna ('')
test_data['Subject'] = test_data['Subject'].fillna ('')

train_data['Message'] = train_data['Message'].fillna ('')
test_data['Message'] = test_data['Message'].fillna ('')

# %%
# Gộp cột Subject và Message lại thành một cột duy nhất là Text 
train_data['Text'] = train_data['Subject'] + ' ' + train_data['Message']
test_data['Text'] = test_data['Subject'] + ' ' + test_data['Message']

# %%
# Chia ra tập huấn luyện và tập kiểm thử 
X_train = train_data['Text']
Y_train = train_data['Spam/Ham']

X_test = test_data['Text']
Y_test = test_data['Spam/Ham']

# %% [markdown]
# # 3 - Xây dựng mô hình

# %%
# Trích xuất đặc trưng bằng TF-IDF
tfidf = TfidfVectorizer(max_features=5000) # giới hạn số lượng từ vựng tối đa là 5000
X_train_tfidf = tfidf.fit_transform(X_train)
X_test_tfidf = tfidf.transform(X_test)

# %%
# Huấn luyện mô hình Naive Bayes
model = MultinomialNB()
model.fit(X_train_tfidf, Y_train)
# Out:
# MultinomialNB()

# %%
# Save the model and vectorizer
joblib.dump(model, 'spam_classifier_model.pkl')
joblib.dump(tfidf, 'tfidf_vectorizer.pkl')
# Out:
# ['tfidf_vectorizer.pkl']

# %%
# Dự đoán nhãn của tập kiểm thử
Y_pred = model.predict(X_test_tfidf)

# %%
# Đánh giá mô hình bằng các độ đo Accuracy, Precision, Recall, F1
accuracy = accuracy_score(Y_test, Y_pred)
precision = precision_score(Y_test, Y_pred , pos_label='spam')
recall = recall_score(Y_test, Y_pred, pos_label='spam')
f1 = f1_score(Y_test, Y_pred , pos_label='spam')

print(f"Accuracy: {accuracy}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1 Score: {f1}")
# Out:
# Accuracy: 0.9818417639429312
# Precision: 0.9753943217665615
# Recall: 0.9891234804862444
# F1 Score: 0.9822109275730623

# %% [markdown]
# # 4 - Thử nghiệm thực tế

# %%
def preprocess_text(text, vectorizer):
    # Giả sử sử dụng cùng vectorizer (TF-IDF)
    return vectorizer.transform([text])

def predict_email(model, vectorizer):
    subject = input("Nhập tiêu đề email: ")
    message = input("Nhập nội dung email: ")

    # Ghép subject và message
    email_text = subject + " " + message

    # Tiền xử lý giống như đã làm với tập dữ liệu ban đầu
    email_vectorized = preprocess_text(email_text, vectorizer)

    # Dự đoán
    prediction = model.predict(email_vectorized)

    # Trả về kết quả
    print("Dự đoán: ", "Spam" if prediction[0] == 'spam' else "Ham")

# Ví dụ sử dụng:
predict_email(model, tfidf)  # model là mô hình đã huấn luyện, tfidf là vectorizer
# Out:
# Dự đoán:  Spam

# %%
def evaluate_on_csv(model, vectorizer, file_path):
    # Đọc file CSV
    data = pd.read_csv(file_path)
    # Thay thế NaN bằng chuỗi rỗng
    data['Subject'] = data['Subject'].fillna('')
    data['Message'] = data['Message'].fillna('')
    
    # Kết hợp 'subject' và 'message' thành một chuỗi
    data['Text'] = data['Subject'] + " " + data['Message']

    # Tiền xử lý dữ liệu
    X = vectorizer.transform(data['Text'])  # Tiền xử lý giống với quá trình huấn luyện
    y_true = data['Spam/Ham']  # Nhãn thực tế (spam hoặc ham)

    # Dự đoán
    y_pred = model.predict(X)

    # Đánh giá kết quả
    accuracy = accuracy_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred, pos_label='spam')
    recall = recall_score(y_true, y_pred, pos_label='spam')
    f1 = f1_score(y_true, y_pred, pos_label='spam')

    print(f"Accuracy: {accuracy}")
    print(f"Precision: {precision}")
    print(f"Recall: {recall}")
    print(f"F1 Score: {f1}")

# Ví dụ sử dụng:
evaluate_on_csv(model, tfidf, "val.csv")  # model là mô hình đã huấn luyện, tfidf là vectorizer
# Out:
# Accuracy: 0.9818417639429312
# Precision: 0.9753943217665615
# Recall: 0.9891234804862444
# F1 Score: 0.9822109275730623
